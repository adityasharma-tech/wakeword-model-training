# %%
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# %%
filename = "../samples/positive/0_sample.wav"

# %%
y, sr = librosa.load(filename)

# %%
D = librosa.stft(y)

# %%
DB = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# %%
plt.figure(figsize=(10, 6))

# %%
img = librosa.display.specshow(DB, sr=sr, x_axis='time', y_axis='log')

# %%
plt.colorbar(img, format='%+2.0f dB')
plt.title('Spectrogram (dB)')
plt.show()
# Out:
# /tmp/ipykernel_3567/1443138367.py:1: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 0 Axes> which fig.colorbar is called on.
#   plt.colorbar(img, format='%+2.0f dB')
