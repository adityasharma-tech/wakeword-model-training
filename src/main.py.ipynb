# %%
import librosa
import numpy as np
import os

# %%
positive_dataset = os.listdir(os.path.join('..', 'samples', 'positive'))
negative_dataset = os.listdir(os.path.join('..', 'samples', 'negative'))

# %%
SAMPLE_RATE = 16000
DURATION = 1.5

# %%
def preprocess_dataset():
    print("Processing dataset...")
    all_mfccs = []
    all_labels = []

    expected_samples = int(SAMPLE_RATE * DURATION)

    for label, dataset in enumerate([negative_dataset, positive_dataset]):
        for index, file_name in enumerate(dataset):
            file_path = os.path.join('..', 'samples', 'positive' if label == 1 else 'negative', file_name)

            try:
                signal, sr = librosa.load(file_path, sr=SAMPLE_RATE)
                if len(signal) > expected_samples:
                        signal = signal[:expected_samples]
                elif len(signal) < expected_samples:
                        signal = np.pad(signal, (0, expected_samples - len(signal)), 'constant')

                mfcc = librosa.feature.mfcc(y=signal, sr=sr, n_mfcc=13, n_fft=2048, hop_length=512)

                mfcc = mfcc.T

                all_mfccs.append(mfcc)
                all_labels.append(label)

                print(f'Processed data {index}:{file_name} success')
            except Exception as e:
                print(f'Failed to process {file_name}: {e}')

    return np.array(all_mfccs), np.array(all_labels)

# %%
X_data, y_data = preprocess_dataset()

print(f"Shape of X_data (MFCCs): {X_data.shape}")
print(f"Shape of y_data (labels): {y_data.shape}")
# Out:
# Processing dataset...
# Processed data 0:90_sample.wav success
# Processed data 1:6_sample.wav success
# Processed data 2:165_sample.wav success
# Processed data 3:399_sample.wav success
# Processed data 4:422_sample.wav success
# Processed data 5:79_sample.wav success
# Processed data 6:349_sample.wav success
# Processed data 7:74_sample.wav success
# Processed data 8:324_sample.wav success
# Processed data 9:125_sample.wav success
# Processed data 10:332_sample.wav success
# Processed data 11:467_sample.wav success
# Processed data 12:118_sample.wav success
# Processed data 13:232_sample.wav success
# Processed data 14:459_sample.wav success
# Processed data 15:242_sample.wav success
# Processed data 16:497_sample.wav success
# Processed data 17:114_sample.wav success
# Processed data 18:237_sample.wav success
# Processed data 19:412_sample.wav success
# Processed data 20:4_sample.wav success
# Processed data 21:476_sample.wav success
# Processed data 22:266_sample.wav success
# Processed data 23:222_sample.wav success
# Processed data 24:238_sample.wav success
# Processed data 25:195_sample.wav success
# Processed data 26:373_sample.wav success
# Processed data 27:112_sample.wav success
# Processed data 28:428_sample.wav success
# Processed data 29:252_sample.wav success
# Processed data 30:205_sample.wav success
# Processed data 31:327_sample.wav success
# Processed data 32:188_sample.wav success
# Processed data 33:374_sample.wav success
# Processed data 34:450_sample.wav success
# Processed data 35:218_sample.wav success
# Processed data 36:105_sample.wav success
# Processed data 37:500_sample.wav success
# Processed data 38:31_sample.wav success
# Processed data 39:81_sample.wav success
# Processed data 40:33_sample.wav success
# Processed data 41:322_sample.wav success
# Processed data 42:364_sample.wav success
# Processed data 43:392_sample.wav success
# Processed data 44:7_sample.wav success
# Processed data 45:386_sample.wav success
# Processed data 46:446_sample.wav success
# Processed data 47:172_sample.wav success
# Processed data 48:170_sample.wav success
# Processed data 49:247_sample.wav success
# Processed data 50:470_sample.wav success
# Processed data 51:354_sample.wav success
# Processed data 52:229_sample.wav success
# Processed data 53:471_sample.wav success
# Processed data 54:348_sample.wav success
# Processed data 55:457_sample.wav success
# Processed data 56:442_sample.wav success
# Processed data 57:109_sample.wav success
# Processed data 58:56_sample.wav success
# Processed data 59:398_sample.wav success
# Processed data 60:17_sample.wav success
# Processed data 61:216_sample.wav success
# Processed data 62:409_sample.wav success
# Processed data 63:12_sample.wav success
# Processed data 64:352_sample.wav success
# Processed data 65:117_sample.wav success
# Processed data 66:417_sample.wav success
# Processed data 67:143_sample.wav success
# Processed data 68:152_sample.wav success
# Processed data 69:308_sample.wav success
# Processed data 70:445_sample.wav success
# Processed data 71:161_sample.wav success
# Processed data 72:279_sample.wav success
# Processed data 73:377_sample.wav success
# Processed data 74:441_sample.wav success
# Processed data 75:76_sample.wav success
# Processed data 76:122_sample.wav success
# Processed data 77:180_sample.wav success
# Processed data 78:356_sample.wav success
# Processed data 79:411_sample.wav success
# Processed data 80:272_sample.wav success
# Processed data 81:220_sample.wav success
# Processed data 82:190_sample.wav success
# Processed data 83:136_sample.wav success
# Processed data 84:340_sample.wav success
# Processed data 85:343_sample.wav success
# Processed data 86:383_sample.wav success
# Processed data 87:131_sample.wav success
# Processed data 88:401_sample.wav success
# Processed data 89:239_sample.wav success
# Processed data 90:367_sample.wav success
# Processed data 91:368_sample.wav success
# Processed data 92:132_sample.wav success
# Processed data 93:259_sample.wav success
# Processed data 94:146_sample.wav success
# Processed data 95:318_sample.wav success
# Processed data 96:331_sample.wav success
# Processed data 97:388_sample.wav success
# Processed data 98:127_sample.wav success
# Processed data 99:301_sample.wav success
# Processed data 100:311_sample.wav success
# Processed data 101:385_sample.wav success
# Processed data 102:338_sample.wav success
# Processed data 103:389_sample.wav success
# Processed data 104:280_sample.wav success
# Processed data 105:248_sample.wav success
# Processed data 106:179_sample.wav success
# Processed data 107:221_sample.wav success
# Processed data 108:419_sample.wav success
# Processed data 109:14_sample.wav success
# Processed data 110:70_sample.wav success
# Processed data 111:39_sample.wav success
# Processed data 112:306_sample.wav success
# Processed data 113:159_sample.wav success
# Processed data 114:359_sample.wav success
# Processed data 115:295_sample.wav success
# Processed data 116:160_sample.wav success
# Processed data 117:429_sample.wav success
# Processed data 118:107_sample.wav success
# Processed data 119:376_sample.wav success
# Processed data 120:440_sample.wav success
# Processed data 121:213_sample.wav success
# Processed data 122:66_sample.wav success
# Processed data 123:228_sample.wav success
# Processed data 124:453_sample.wav success
# Processed data 125:458_sample.wav success
# Processed data 126:94_sample.wav success
# Processed data 127:305_sample.wav success
# Processed data 128:341_sample.wav success
# Processed data 129:307_sample.wav success
# Processed data 130:47_sample.wav success
# Processed data 131:204_sample.wav success
# Processed data 132:323_sample.wav success
# Processed data 133:380_sample.wav success
# Processed data 134:236_sample.wav success
# Processed data 135:334_sample.wav success
# Processed data 136:19_sample.wav success
# Processed data 137:473_sample.wav success
# Processed data 138:494_sample.wav success
# Processed data 139:342_sample.wav success
# Processed data 140:84_sample.wav success
# Processed data 141:147_sample.wav success
# Processed data 142:30_sample.wav success
# Processed data 143:120_sample.wav success
# Processed data 144:443_sample.wav success
# Processed data 145:366_sample.wav success
# Processed data 146:28_sample.wav success
# Processed data 147:423_sample.wav success
# Processed data 148:495_sample.wav success
# Processed data 149:144_sample.wav success
# Processed data 150:287_sample.wav success
# Processed data 151:249_sample.wav success
# Processed data 152:480_sample.wav success
# Processed data 153:347_sample.wav success
# Processed data 154:171_sample.wav success
# Processed data 155:11_sample.wav success
# Processed data 156:34_sample.wav success
# Processed data 157:58_sample.wav success
# Processed data 158:217_sample.wav success
# Processed data 159:313_sample.wav success
# Processed data 160:163_sample.wav success
# Processed data 161:234_sample.wav success
# Processed data 162:300_sample.wav success
# Processed data 163:138_sample.wav success
# Processed data 164:140_sample.wav success
# Processed data 165:267_sample.wav success
# Processed data 166:477_sample.wav success
# Processed data 167:0_sample.wav success
# Processed data 168:402_sample.wav success
# Processed data 169:20_sample.wav success
# Processed data 170:141_sample.wav success
# Processed data 171:293_sample.wav success
# Processed data 172:100_sample.wav success
# Processed data 173:219_sample.wav success
# Processed data 174:260_sample.wav success
# Processed data 175:92_sample.wav success
# Processed data 176:391_sample.wav success
# Processed data 177:456_sample.wav success
# Processed data 178:261_sample.wav success
# Processed data 179:181_sample.wav success
# Processed data 180:321_sample.wav success
# Processed data 181:241_sample.wav success
# Processed data 182:65_sample.wav success
# Processed data 183:244_sample.wav success
# Processed data 184:226_sample.wav success
# Processed data 185:55_sample.wav success
# Processed data 186:72_sample.wav success
# Processed data 187:262_sample.wav success
# Processed data 188:176_sample.wav success
# Processed data 189:86_sample.wav success
# Processed data 190:420_sample.wav success
# Processed data 191:283_sample.wav success
# Processed data 192:197_sample.wav success
# Processed data 193:289_sample.wav success
# Processed data 194:257_sample.wav success
# Processed data 195:253_sample.wav success
# Processed data 196:230_sample.wav success
# Processed data 197:353_sample.wav success
# Processed data 198:89_sample.wav success
# Processed data 199:333_sample.wav success
# Processed data 200:378_sample.wav success
# Processed data 201:414_sample.wav success
# Processed data 202:278_sample.wav success
# Processed data 203:268_sample.wav success
# Processed data 204:381_sample.wav success
# Processed data 205:88_sample.wav success
# Processed data 206:460_sample.wav success
# Processed data 207:408_sample.wav success
# Processed data 208:447_sample.wav success
# Processed data 209:13_sample.wav success
# Processed data 210:42_sample.wav success
# Processed data 211:80_sample.wav success
# Processed data 212:104_sample.wav success
# Processed data 213:139_sample.wav success
# Processed data 214:370_sample.wav success
# Processed data 215:384_sample.wav success
# Processed data 216:400_sample.wav success
# Processed data 217:254_sample.wav success
# Processed data 218:29_sample.wav success
# Processed data 219:463_sample.wav success
# Processed data 220:431_sample.wav success
# Processed data 221:452_sample.wav success
# Processed data 222:496_sample.wav success
# Processed data 223:361_sample.wav success
# Processed data 224:49_sample.wav success
# Processed data 225:465_sample.wav success
# Processed data 226:98_sample.wav success
# Processed data 227:10_sample.wav success
# Processed data 228:263_sample.wav success
# Processed data 229:461_sample.wav success
# Processed data 230:54_sample.wav success
# Processed data 231:358_sample.wav success
# Processed data 232:16_sample.wav success
# Processed data 233:345_sample.wav success
# Processed data 234:215_sample.wav success
# Processed data 235:499_sample.wav success
# Processed data 236:224_sample.wav success
# Processed data 237:85_sample.wav success
# Processed data 238:22_sample.wav success
# Processed data 239:113_sample.wav success
# Processed data 240:198_sample.wav success
# Processed data 241:106_sample.wav success
# Processed data 242:369_sample.wav success
# Processed data 243:110_sample.wav success
# Processed data 244:475_sample.wav success
# Processed data 245:415_sample.wav success
# Processed data 246:9_sample.wav success
# Processed data 247:329_sample.wav success
# Processed data 248:335_sample.wav success
# Processed data 249:73_sample.wav success
# Processed data 250:187_sample.wav success
# Processed data 251:466_sample.wav success
# Processed data 252:273_sample.wav success
# Processed data 253:60_sample.wav success
# Processed data 254:315_sample.wav success
# Processed data 255:5_sample.wav success
# Processed data 256:387_sample.wav success
# Processed data 257:240_sample.wav success
# Processed data 258:154_sample.wav success
# Processed data 259:116_sample.wav success
# Processed data 260:24_sample.wav success
# Processed data 261:372_sample.wav success
# Processed data 262:320_sample.wav success
# Processed data 263:59_sample.wav success
# Processed data 264:474_sample.wav success
# Processed data 265:493_sample.wav success
# Processed data 266:418_sample.wav success
# Processed data 267:43_sample.wav success
# Processed data 268:137_sample.wav success
# Processed data 269:35_sample.wav success
# Processed data 270:285_sample.wav success
# Processed data 271:121_sample.wav success
# Processed data 272:265_sample.wav success
# Processed data 273:208_sample.wav success
# Processed data 274:99_sample.wav success
# Processed data 275:21_sample.wav success
# Processed data 276:23_sample.wav success
# Processed data 277:426_sample.wav success
# Processed data 278:288_sample.wav success
# Processed data 279:284_sample.wav success
# Processed data 280:111_sample.wav success
# Processed data 281:191_sample.wav success
# Processed data 282:246_sample.wav success
# Processed data 283:355_sample.wav success
# Processed data 284:469_sample.wav success
# Processed data 285:296_sample.wav success
# Processed data 286:135_sample.wav success
# Processed data 287:319_sample.wav success
# Processed data 288:133_sample.wav success
# Processed data 289:488_sample.wav success
# Processed data 290:158_sample.wav success
# Processed data 291:123_sample.wav success
# Processed data 292:214_sample.wav success
# Processed data 293:410_sample.wav success
# Processed data 294:405_sample.wav success
# Processed data 295:303_sample.wav success
# Processed data 296:290_sample.wav success
# Processed data 297:206_sample.wav success
# Processed data 298:209_sample.wav success
# Processed data 299:184_sample.wav success
# Processed data 300:395_sample.wav success
# Processed data 301:314_sample.wav success
# Processed data 302:62_sample.wav success
# Processed data 303:478_sample.wav success
# Processed data 304:77_sample.wav success
# Processed data 305:264_sample.wav success
# Processed data 306:32_sample.wav success
# Processed data 307:129_sample.wav success
# Processed data 308:119_sample.wav success
# Processed data 309:69_sample.wav success
# Processed data 310:256_sample.wav success
# Processed data 311:439_sample.wav success
# Processed data 312:350_sample.wav success
# Processed data 313:393_sample.wav success
# Processed data 314:63_sample.wav success
# Processed data 315:231_sample.wav success
# Processed data 316:379_sample.wav success
# Processed data 317:491_sample.wav success
# Processed data 318:437_sample.wav success
# Processed data 319:421_sample.wav success
# Processed data 320:192_sample.wav success
# Processed data 321:424_sample.wav success
# Processed data 322:451_sample.wav success
# Processed data 323:115_sample.wav success
# Processed data 324:175_sample.wav success
# Processed data 325:149_sample.wav success
# Processed data 326:269_sample.wav success
# Processed data 327:351_sample.wav success
# Processed data 328:201_sample.wav success
# Processed data 329:45_sample.wav success
# Processed data 330:435_sample.wav success
# Processed data 331:462_sample.wav success
# Processed data 332:243_sample.wav success
# Processed data 333:186_sample.wav success
# Processed data 334:464_sample.wav success
# Processed data 335:145_sample.wav success
# Processed data 336:404_sample.wav success
# Processed data 337:57_sample.wav success
# Processed data 338:337_sample.wav success
# Processed data 339:162_sample.wav success
# Processed data 340:126_sample.wav success
# Processed data 341:75_sample.wav success
# Processed data 342:396_sample.wav success
# Processed data 343:454_sample.wav success
# Processed data 344:382_sample.wav success
# Processed data 345:449_sample.wav success
# Processed data 346:317_sample.wav success
# Processed data 347:326_sample.wav success
# Processed data 348:3_sample.wav success
# Processed data 349:189_sample.wav success
# Processed data 350:134_sample.wav success
# Processed data 351:481_sample.wav success
# Processed data 352:309_sample.wav success
# Processed data 353:297_sample.wav success
# Processed data 354:371_sample.wav success
# Processed data 355:202_sample.wav success
# Processed data 356:183_sample.wav success
# Processed data 357:225_sample.wav success
# Processed data 358:271_sample.wav success
# Processed data 359:102_sample.wav success
# Processed data 360:427_sample.wav success
# Processed data 361:36_sample.wav success
# Processed data 362:375_sample.wav success
# Processed data 363:472_sample.wav success
# Processed data 364:38_sample.wav success
# Processed data 365:193_sample.wav success
# Processed data 366:148_sample.wav success
# Processed data 367:108_sample.wav success
# Processed data 368:207_sample.wav success
# Processed data 369:436_sample.wav success
# Processed data 370:294_sample.wav success
# Processed data 371:298_sample.wav success
# Processed data 372:68_sample.wav success
# Processed data 373:479_sample.wav success
# Processed data 374:413_sample.wav success
# Processed data 375:233_sample.wav success
# Processed data 376:258_sample.wav success
# Processed data 377:498_sample.wav success
# Processed data 378:468_sample.wav success
# Processed data 379:212_sample.wav success
# Processed data 380:486_sample.wav success
# Processed data 381:310_sample.wav success
# Processed data 382:8_sample.wav success
# Processed data 383:282_sample.wav success
# Processed data 384:292_sample.wav success
# Processed data 385:15_sample.wav success
# Processed data 386:156_sample.wav success
# Processed data 387:485_sample.wav success
# Processed data 388:223_sample.wav success
# Processed data 389:304_sample.wav success
# Processed data 390:166_sample.wav success
# Processed data 391:255_sample.wav success
# Processed data 392:177_sample.wav success
# Processed data 393:103_sample.wav success
# Processed data 394:281_sample.wav success
# Processed data 395:299_sample.wav success
# Processed data 396:169_sample.wav success
# Processed data 397:194_sample.wav success
# Processed data 398:41_sample.wav success
# Processed data 399:316_sample.wav success
# Processed data 400:196_sample.wav success
# Processed data 401:325_sample.wav success
# Processed data 402:406_sample.wav success
# Processed data 403:482_sample.wav success
# Processed data 404:312_sample.wav success
# Processed data 405:438_sample.wav success
# Processed data 406:274_sample.wav success
# Processed data 407:339_sample.wav success
# Processed data 408:363_sample.wav success
# Processed data 409:330_sample.wav success
# Processed data 410:251_sample.wav success
# Processed data 411:71_sample.wav success
# Processed data 412:52_sample.wav success
# Processed data 413:357_sample.wav success
# Processed data 414:124_sample.wav success
# Processed data 415:434_sample.wav success
# Processed data 416:167_sample.wav success
# Processed data 417:276_sample.wav success
# Processed data 418:97_sample.wav success
# Processed data 419:142_sample.wav success
# Processed data 420:87_sample.wav success
# Processed data 421:455_sample.wav success
# Processed data 422:336_sample.wav success
# Processed data 423:433_sample.wav success
# Processed data 424:203_sample.wav success
# Processed data 425:211_sample.wav success
# Processed data 426:250_sample.wav success
# Processed data 427:40_sample.wav success
# Processed data 428:27_sample.wav success
# Processed data 429:444_sample.wav success
# Processed data 430:185_sample.wav success
# Processed data 431:344_sample.wav success
# Processed data 432:130_sample.wav success
# Processed data 433:346_sample.wav success
# Processed data 434:390_sample.wav success
# Processed data 435:270_sample.wav success
# Processed data 436:168_sample.wav success
# Processed data 437:157_sample.wav success
# Processed data 438:150_sample.wav success
# Processed data 439:44_sample.wav success
# Processed data 440:275_sample.wav success
# Processed data 441:53_sample.wav success
# Processed data 442:291_sample.wav success
# Processed data 443:51_sample.wav success
# Processed data 444:78_sample.wav success
# Processed data 445:91_sample.wav success
# Processed data 446:153_sample.wav success
# Processed data 447:37_sample.wav success
# Processed data 448:26_sample.wav success
# Processed data 449:151_sample.wav success
# Processed data 450:173_sample.wav success
# Processed data 451:155_sample.wav success
# Processed data 452:182_sample.wav success
# Processed data 453:83_sample.wav success
# Processed data 454:164_sample.wav success
# Processed data 455:200_sample.wav success
# Processed data 456:199_sample.wav success
# Processed data 457:2_sample.wav success
# Processed data 458:93_sample.wav success
# Processed data 459:360_sample.wav success
# Processed data 460:489_sample.wav success
# Processed data 461:487_sample.wav success
# Processed data 462:394_sample.wav success
# Processed data 463:245_sample.wav success
# Processed data 464:25_sample.wav success
# Processed data 465:430_sample.wav success
# Processed data 466:96_sample.wav success
# Processed data 467:50_sample.wav success
# Processed data 468:302_sample.wav success
# Processed data 469:227_sample.wav success
# Processed data 470:362_sample.wav success
# Processed data 471:416_sample.wav success
# Processed data 472:432_sample.wav success
# Processed data 473:64_sample.wav success
# Processed data 474:210_sample.wav success
# Processed data 475:95_sample.wav success
# Processed data 476:48_sample.wav success
# Processed data 477:448_sample.wav success
# Processed data 478:128_sample.wav success
# Processed data 479:18_sample.wav success
# Processed data 480:484_sample.wav success
# Processed data 481:174_sample.wav success
# Processed data 482:277_sample.wav success
# Processed data 483:365_sample.wav success
# Processed data 484:483_sample.wav success
# Processed data 485:46_sample.wav success
# Processed data 486:61_sample.wav success
# Processed data 487:82_sample.wav success
# Processed data 488:67_sample.wav success
# Processed data 489:403_sample.wav success
# Processed data 490:492_sample.wav success
# Processed data 491:328_sample.wav success
# Processed data 492:286_sample.wav success
# Processed data 493:407_sample.wav success
# Processed data 494:425_sample.wav success
# Processed data 495:1_sample.wav success
# Processed data 496:397_sample.wav success
# Processed data 497:235_sample.wav success
# Processed data 498:490_sample.wav success
# Processed data 499:101_sample.wav success
# Processed data 500:178_sample.wav success
# Processed data 0:90_sample.wav success
# Processed data 1:6_sample.wav success
# Processed data 2:399_sample.wav success
# Processed data 3:79_sample.wav success
# Processed data 4:349_sample.wav success
# Processed data 5:74_sample.wav success
# Processed data 6:324_sample.wav success
# Processed data 7:125_sample.wav success
# Processed data 8:332_sample.wav success
# Processed data 9:118_sample.wav success
# Processed data 10:232_sample.wav success
# Processed data 11:242_sample.wav success
# Processed data 12:114_sample.wav success
# Processed data 13:237_sample.wav success
# Processed data 14:4_sample.wav success
# Processed data 15:266_sample.wav success
# Processed data 16:222_sample.wav success
# Processed data 17:238_sample.wav success
# Processed data 18:373_sample.wav success
# Processed data 19:112_sample.wav success
# Processed data 20:252_sample.wav success
# Processed data 21:205_sample.wav success
# Processed data 22:327_sample.wav success
# Processed data 23:188_sample.wav success
# Processed data 24:374_sample.wav success
# Processed data 25:218_sample.wav success
# Processed data 26:105_sample.wav success
# Processed data 27:81_sample.wav success
# Processed data 28:322_sample.wav success
# Processed data 29:392_sample.wav success
# Processed data 30:7_sample.wav success
# Processed data 31:386_sample.wav success
# Processed data 32:172_sample.wav success
# Processed data 33:247_sample.wav success
# Processed data 34:354_sample.wav success
# Processed data 35:229_sample.wav success
# Processed data 36:348_sample.wav success
# Processed data 37:109_sample.wav success
# Processed data 38:56_sample.wav success
# Processed data 39:398_sample.wav success
# Processed data 40:17_sample.wav success
# Processed data 41:216_sample.wav success
# Processed data 42:12_sample.wav success
# Processed data 43:352_sample.wav success
# Processed data 44:117_sample.wav success
# Processed data 45:152_sample.wav success
# Processed data 46:308_sample.wav success
# Processed data 47:161_sample.wav success
# Processed data 48:279_sample.wav success
# Processed data 49:377_sample.wav success
# Processed data 50:76_sample.wav success
# Processed data 51:122_sample.wav success
# Processed data 52:180_sample.wav success
# Processed data 53:356_sample.wav success
# Processed data 54:272_sample.wav success
# Processed data 55:220_sample.wav success
# Processed data 56:190_sample.wav success
# Processed data 57:136_sample.wav success
# Processed data 58:340_sample.wav success
# Processed data 59:343_sample.wav success
# Processed data 60:383_sample.wav success
# Processed data 61:131_sample.wav success
# Processed data 62:239_sample.wav success
# Processed data 63:367_sample.wav success
# Processed data 64:368_sample.wav success
# Processed data 65:132_sample.wav success
# Processed data 66:259_sample.wav success
# Processed data 67:146_sample.wav success
# Processed data 68:318_sample.wav success
# Processed data 69:331_sample.wav success
# Processed data 70:127_sample.wav success
# Processed data 71:301_sample.wav success
# Processed data 72:311_sample.wav success
# Processed data 73:385_sample.wav success
# Processed data 74:338_sample.wav success
# Processed data 75:280_sample.wav success
# Processed data 76:179_sample.wav success
# Processed data 77:221_sample.wav success
# Processed data 78:14_sample.wav success
# Processed data 79:70_sample.wav success
# Processed data 80:39_sample.wav success
# Processed data 81:306_sample.wav success
# Processed data 82:159_sample.wav success
# Processed data 83:359_sample.wav success
# Processed data 84:295_sample.wav success
# Processed data 85:160_sample.wav success
# Processed data 86:107_sample.wav success
# Processed data 87:376_sample.wav success
# Processed data 88:213_sample.wav success
# Processed data 89:66_sample.wav success
# Processed data 90:228_sample.wav success
# Processed data 91:94_sample.wav success
# Processed data 92:305_sample.wav success
# Processed data 93:341_sample.wav success
# Processed data 94:307_sample.wav success
# Processed data 95:47_sample.wav success
# Processed data 96:204_sample.wav success
# Processed data 97:323_sample.wav success
# Processed data 98:380_sample.wav success
# Processed data 99:236_sample.wav success
# Processed data 100:334_sample.wav success
# Processed data 101:342_sample.wav success
# Processed data 102:84_sample.wav success
# Processed data 103:147_sample.wav success
# Processed data 104:30_sample.wav success
# Processed data 105:120_sample.wav success
# Processed data 106:366_sample.wav success
# Processed data 107:28_sample.wav success
# Processed data 108:144_sample.wav success
# Processed data 109:287_sample.wav success
# Processed data 110:249_sample.wav success
# Processed data 111:347_sample.wav success
# Processed data 112:171_sample.wav success
# Processed data 113:11_sample.wav success
# Processed data 114:34_sample.wav success
# Processed data 115:58_sample.wav success
# Processed data 116:313_sample.wav success
# Processed data 117:163_sample.wav success
# Processed data 118:234_sample.wav success
# Processed data 119:300_sample.wav success
# Processed data 120:138_sample.wav success
# Processed data 121:140_sample.wav success
# Processed data 122:267_sample.wav success
# Processed data 123:0_sample.wav success
# Processed data 124:141_sample.wav success
# Processed data 125:293_sample.wav success
# Processed data 126:100_sample.wav success
# Processed data 127:219_sample.wav success
# Processed data 128:260_sample.wav success
# Processed data 129:92_sample.wav success
# Processed data 130:391_sample.wav success
# Processed data 131:261_sample.wav success
# Processed data 132:181_sample.wav success
# Processed data 133:321_sample.wav success
# Processed data 134:241_sample.wav success
# Processed data 135:65_sample.wav success
# Processed data 136:226_sample.wav success
# Processed data 137:55_sample.wav success
# Processed data 138:72_sample.wav success
# Processed data 139:262_sample.wav success
# Processed data 140:176_sample.wav success
# Processed data 141:86_sample.wav success
# Processed data 142:283_sample.wav success
# Processed data 143:197_sample.wav success
# Processed data 144:289_sample.wav success
# Processed data 145:257_sample.wav success
# Processed data 146:253_sample.wav success
# Processed data 147:230_sample.wav success
# Processed data 148:353_sample.wav success
# Processed data 149:89_sample.wav success
# Processed data 150:333_sample.wav success
# Processed data 151:378_sample.wav success
# Processed data 152:278_sample.wav success
# Processed data 153:268_sample.wav success
# Processed data 154:381_sample.wav success
# Processed data 155:88_sample.wav success
# Processed data 156:13_sample.wav success
# Processed data 157:42_sample.wav success
# Processed data 158:80_sample.wav success
# Processed data 159:104_sample.wav success
# Processed data 160:139_sample.wav success
# Processed data 161:370_sample.wav success
# Processed data 162:384_sample.wav success
# Processed data 163:400_sample.wav success
# Processed data 164:254_sample.wav success
# Processed data 165:29_sample.wav success
# Processed data 166:361_sample.wav success
# Processed data 167:49_sample.wav success
# Processed data 168:98_sample.wav success
# Processed data 169:10_sample.wav success
# Processed data 170:263_sample.wav success
# Processed data 171:54_sample.wav success
# Processed data 172:358_sample.wav success
# Processed data 173:16_sample.wav success
# Processed data 174:345_sample.wav success
# Processed data 175:215_sample.wav success
# Processed data 176:85_sample.wav success
# Processed data 177:106_sample.wav success
# Processed data 178:369_sample.wav success
# Processed data 179:110_sample.wav success
# Processed data 180:329_sample.wav success
# Processed data 181:335_sample.wav success
# Processed data 182:187_sample.wav success
# Processed data 183:273_sample.wav success
# Processed data 184:60_sample.wav success
# Processed data 185:5_sample.wav success
# Processed data 186:387_sample.wav success
# Processed data 187:240_sample.wav success
# Processed data 188:154_sample.wav success
# Processed data 189:116_sample.wav success
# Processed data 190:24_sample.wav success
# Processed data 191:372_sample.wav success
# Processed data 192:320_sample.wav success
# Processed data 193:59_sample.wav success
# Processed data 194:43_sample.wav success
# Processed data 195:137_sample.wav success
# Processed data 196:35_sample.wav success
# Processed data 197:285_sample.wav success
# Processed data 198:121_sample.wav success
# Processed data 199:265_sample.wav success
# Processed data 200:208_sample.wav success
# Processed data 201:99_sample.wav success
# Processed data 202:21_sample.wav success
# Processed data 203:23_sample.wav success
# Processed data 204:288_sample.wav success
# Processed data 205:284_sample.wav success
# Processed data 206:111_sample.wav success
# Processed data 207:191_sample.wav success
# Processed data 208:246_sample.wav success
# Processed data 209:355_sample.wav success
# Processed data 210:296_sample.wav success
# Processed data 211:135_sample.wav success
# Processed data 212:319_sample.wav success
# Processed data 213:133_sample.wav success
# Processed data 214:158_sample.wav success
# Processed data 215:123_sample.wav success
# Processed data 216:214_sample.wav success
# Processed data 217:303_sample.wav success
# Processed data 218:290_sample.wav success
# Processed data 219:206_sample.wav success
# Processed data 220:209_sample.wav success
# Processed data 221:184_sample.wav success
# Processed data 222:395_sample.wav success
# Processed data 223:314_sample.wav success
# Processed data 224:62_sample.wav success
# Processed data 225:77_sample.wav success
# Processed data 226:264_sample.wav success
# Processed data 227:32_sample.wav success
# Processed data 228:129_sample.wav success
# Processed data 229:119_sample.wav success
# Processed data 230:69_sample.wav success
# Processed data 231:256_sample.wav success
# Processed data 232:350_sample.wav success
# Processed data 233:393_sample.wav success
# Processed data 234:63_sample.wav success
# Processed data 235:231_sample.wav success
# Processed data 236:379_sample.wav success
# Processed data 237:192_sample.wav success
# Processed data 238:115_sample.wav success
# Processed data 239:269_sample.wav success
# Processed data 240:351_sample.wav success
# Processed data 241:201_sample.wav success
# Processed data 242:45_sample.wav success
# Processed data 243:243_sample.wav success
# Processed data 244:186_sample.wav success
# Processed data 245:145_sample.wav success
# Processed data 246:57_sample.wav success
# Processed data 247:337_sample.wav success
# Processed data 248:162_sample.wav success
# Processed data 249:126_sample.wav success
# Processed data 250:75_sample.wav success
# Processed data 251:396_sample.wav success
# Processed data 252:382_sample.wav success
# Processed data 253:317_sample.wav success
# Processed data 254:326_sample.wav success
# Processed data 255:3_sample.wav success
# Processed data 256:189_sample.wav success
# Processed data 257:134_sample.wav success
# Processed data 258:309_sample.wav success
# Processed data 259:297_sample.wav success
# Processed data 260:371_sample.wav success
# Processed data 261:202_sample.wav success
# Processed data 262:183_sample.wav success
# Processed data 263:225_sample.wav success
# Processed data 264:271_sample.wav success
# Processed data 265:102_sample.wav success
# Processed data 266:36_sample.wav success
# Processed data 267:375_sample.wav success
# Processed data 268:193_sample.wav success
# Processed data 269:148_sample.wav success
# Processed data 270:108_sample.wav success
# Processed data 271:207_sample.wav success
# Processed data 272:294_sample.wav success
# Processed data 273:298_sample.wav success
# Processed data 274:68_sample.wav success
# Processed data 275:233_sample.wav success
# Processed data 276:258_sample.wav success
# Processed data 277:212_sample.wav success
# Processed data 278:310_sample.wav success
# Processed data 279:8_sample.wav success
# Processed data 280:282_sample.wav success
# Processed data 281:292_sample.wav success
# Processed data 282:15_sample.wav success
# Processed data 283:156_sample.wav success
# Processed data 284:223_sample.wav success
# Processed data 285:304_sample.wav success
# Processed data 286:166_sample.wav success
# Processed data 287:255_sample.wav success
# Processed data 288:177_sample.wav success
# Processed data 289:103_sample.wav success
# Processed data 290:281_sample.wav success
# Processed data 291:299_sample.wav success
# Processed data 292:169_sample.wav success
# Processed data 293:194_sample.wav success
# Processed data 294:41_sample.wav success
# Processed data 295:316_sample.wav success
# Processed data 296:196_sample.wav success
# Processed data 297:325_sample.wav success
# Processed data 298:312_sample.wav success
# Processed data 299:274_sample.wav success
# Processed data 300:339_sample.wav success
# Processed data 301:363_sample.wav success
# Processed data 302:330_sample.wav success
# Processed data 303:251_sample.wav success
# Processed data 304:71_sample.wav success
# Processed data 305:52_sample.wav success
# Processed data 306:357_sample.wav success
# Processed data 307:124_sample.wav success
# Processed data 308:167_sample.wav success
# Processed data 309:276_sample.wav success
# Processed data 310:97_sample.wav success
# Processed data 311:142_sample.wav success
# Processed data 312:87_sample.wav success
# Processed data 313:336_sample.wav success
# Processed data 314:203_sample.wav success
# Processed data 315:211_sample.wav success
# Processed data 316:250_sample.wav success
# Processed data 317:40_sample.wav success
# Processed data 318:27_sample.wav success
# Processed data 319:185_sample.wav success
# Processed data 320:344_sample.wav success
# Processed data 321:130_sample.wav success
# Processed data 322:346_sample.wav success
# Processed data 323:390_sample.wav success
# Processed data 324:270_sample.wav success
# Processed data 325:168_sample.wav success
# Processed data 326:157_sample.wav success
# Processed data 327:150_sample.wav success
# Processed data 328:44_sample.wav success
# Processed data 329:275_sample.wav success
# Processed data 330:53_sample.wav success
# Processed data 331:291_sample.wav success
# Processed data 332:51_sample.wav success
# Processed data 333:78_sample.wav success
# Processed data 334:91_sample.wav success
# Processed data 335:153_sample.wav success
# Processed data 336:37_sample.wav success
# Processed data 337:26_sample.wav success
# Processed data 338:151_sample.wav success
# Processed data 339:173_sample.wav success
# Processed data 340:155_sample.wav success
# Processed data 341:182_sample.wav success
# Processed data 342:83_sample.wav success
# Processed data 343:164_sample.wav success
# Processed data 344:200_sample.wav success
# Processed data 345:199_sample.wav success
# Processed data 346:2_sample.wav success
# Processed data 347:93_sample.wav success
# Processed data 348:360_sample.wav success
# Processed data 349:394_sample.wav success
# Processed data 350:245_sample.wav success
# Processed data 351:25_sample.wav success
# Processed data 352:96_sample.wav success
# Processed data 353:50_sample.wav success
# Processed data 354:302_sample.wav success
# Processed data 355:227_sample.wav success
# Processed data 356:362_sample.wav success
# Processed data 357:64_sample.wav success
# Processed data 358:210_sample.wav success
# Processed data 359:95_sample.wav success
# Processed data 360:48_sample.wav success
# Processed data 361:128_sample.wav success
# Processed data 362:18_sample.wav success
# Processed data 363:174_sample.wav success
# Processed data 364:277_sample.wav success
# Processed data 365:365_sample.wav success
# Processed data 366:46_sample.wav success
# Processed data 367:61_sample.wav success
# Processed data 368:82_sample.wav success
# Processed data 369:67_sample.wav success
# Processed data 370:328_sample.wav success
# Processed data 371:286_sample.wav success
# Processed data 372:1_sample.wav success
# Processed data 373:397_sample.wav success
# Processed data 374:235_sample.wav success
# Processed data 375:101_sample.wav success
# Processed data 376:178_sample.wav success
# Shape of X_data (MFCCs): (878, 47, 13)
# Shape of y_data (labels): (878,)

# %%
X_data = X_data[..., np.newaxis]

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# 2025-09-05 00:07:44.981536: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_data, y_data, test_size=0.2, random_state=42, stratify=y_data
)

# %% [markdown]
# Data split into training and testing sets

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (702, 47, 13, 1)
# X_test shape: (176, 47, 13, 1)

# %%
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# %%
model = models.Sequential([
    # Input Layer
    layers.Input(shape=input_shape),

    # First Convolutional Block
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # Second Convolutional Block
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),

    # Flatten the features to feed into the dense layer
    layers.Flatten(),

    # Dense Layer for classification
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5), # Dropout helps prevent overfitting

    # Output Layer
    # Sigmoid is used for binary (2-class) classification
    layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 45, 11, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 22, 5, 32)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 20, 3, 64)      │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 10, 1, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 640)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59,905 (234.00 KB)
#  Trainable params: 59,905 (234.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy', # Perfect for Yes/No (1/0) classification
    metrics=['accuracy']
)

# %% [markdown]
# Model Training

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.6652 - loss: 1.8361 - val_accuracy: 0.8807 - val_loss: 0.3795
# Epoch 2/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8063 - loss: 0.4705 - val_accuracy: 0.8920 - val_loss: 0.3124
# Epoch 3/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8618 - loss: 0.3483 - val_accuracy: 0.8807 - val_loss: 0.2771
# Epoch 4/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8960 - loss: 0.2878 - val_accuracy: 0.9148 - val_loss: 0.1791
# Epoch 5/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9117 - loss: 0.2529 - val_accuracy: 0.9432 - val_loss: 0.1418
# Epoch 6/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9245 - loss: 0.2094 - val_accuracy: 0.9318 - val_loss: 0.1415
# Epoch 7/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9345 - loss: 0.1967 - val_accuracy: 0.9318 - val_loss: 0.1551
# Epoch 8/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9444 - loss: 0.1701 - val_accuracy: 0.9432 - val_loss: 0.1706
# Epoch 9/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9316 - loss: 0.2088 - val_accuracy: 0.9318 - val_loss: 0.1384
# Epoch 10/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9501 - loss: 0.1524 - val_accuracy: 0.9432 - val_loss: 0.1304
# Epoch 11/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9202 - loss: 0.1913 - val_accuracy: 0.9375 - val_loss: 0.1549
# Epoch 12/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9544 - loss: 0.1420 - val_accuracy: 0.9489 - val_loss: 0.1649
# Epoch 13/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9487 - loss: 0.1528 - val_accuracy: 0.9602 - val_loss: 0.1252
# Epoch 14/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9544 - loss: 0.1169 - val_accuracy: 0.9318 - val_loss: 0.1472
# Epoch 15/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9544 - loss: 0.1349 - val_accuracy: 0.9318 - val_loss: 0.1346
# Epoch 16/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9672 - loss: 0.0879 - val_accuracy: 0.9432 - val_loss: 0.2066
# Epoch 17/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9630 - loss: 0.1007 - val_accuracy: 0.9489 - val_loss: 0.1468
# Epoch 18/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9758 - loss: 0.0795 - val_accuracy: 0.9432 - val_loss: 0.1467
# Epoch 19/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9630 - loss: 0.1142 - val_accuracy: 0.9489 - val_loss: 0.1642
# Epoch 20/20
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9729 - loss: 0.0744 - val_accuracy: 0.9432 - val_loss: 0.1456

# %% [markdown]
# Training Complete

# %%
model.save('wake_word.keras')
